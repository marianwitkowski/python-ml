# %%
# !pip -q install lazypredict

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("https://www.dropbox.com/s/ion3vjn7pkdh7zk/otodom.csv?dl=1", usecols=[1,2,3,4,5,6])
df = df.query( " cena > 150_000 and cena < 800_000 ")
df.head()
# Out:
#      cena  liczba_pieter  liczba_pokoi  pietro  powierzchnia  rok_budowy
# 2  640659              4             3       2         64.13        2019
# 3  410000             12             2       4         36.30        1975
# 4  415900             10             2       6         31.06        1974
# 5  550000              4             3       3         51.00        1976
# 6  444000              4             2       1         44.80        2003

# %%
X = df.iloc[:, 1:]
y = df.cena
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)

models
# Out:
# 100%|██████████| 42/42 [00:09<00:00,  4.66it/s]
#                                          Adjusted R-Squared  ...  Time Taken
# Model                                                        ...
# ExtraTreesRegressor                                    0.84  ...        0.47
# RandomForestRegressor                                  0.83  ...        0.65
# LGBMRegressor                                          0.82  ...        0.11
# HistGradientBoostingRegressor                          0.81  ...        0.47
# BaggingRegressor                                       0.81  ...        0.09
# XGBRegressor                                           0.81  ...        0.18
# GradientBoostingRegressor                              0.79  ...        0.22
# KNeighborsRegressor                                    0.77  ...        0.04
# DecisionTreeRegressor                                  0.73  ...        0.03
# ExtraTreeRegressor                                     0.71  ...        0.03
# AdaBoostRegressor                                      0.69  ...        0.12
# OrthogonalMatchingPursuit                              0.65  ...        0.02
# ElasticNetCV                                           0.01  ...        0.14
# DummyRegressor                                        -0.01  ...        0.02
# SVR                                                   -0.01  ...        0.45
# NuSVR                                                 -0.01  ...        0.42
# GeneralizedLinearRegressor                            -8.19  ...        0.04
# TweedieRegressor                                      -8.19  ...        0.02
# RANSACRegressor                                      -15.37  ...        0.08
# PassiveAggressiveRegressor                           -16.53  ...        0.21
# ElasticNet                                           -16.84  ...        0.02
# LinearSVR                                            -21.02  ...        0.02
# MLPRegressor                                         -21.04  ...        2.97
# HuberRegressor                                       -22.85  ...        0.05
# LassoCV                                              -31.01  ...        0.19
# LassoLars                                            -31.13  ...        0.04
# Lasso                                                -31.24  ...        0.03
# OrthogonalMatchingPursuitCV                          -31.24  ...        0.03
# LarsCV                                               -31.24  ...        0.04
# LassoLarsIC                                          -31.24  ...        0.02
# LassoLarsCV                                          -31.24  ...        0.07
# Lars                                                 -31.24  ...        0.03
# LinearRegression                                     -31.24  ...        0.02
# TransformedTargetRegressor                           -31.24  ...        0.02
# RidgeCV                                              -31.26  ...        0.03
# Ridge                                                -31.26  ...        0.02
# BayesianRidge                                        -31.28  ...        0.02
# SGDRegressor                                         -31.76  ...        0.03
# KernelRidge                                          -50.50  ...        0.54
# GaussianProcessRegressor                          -18751.68  ...        0.91
# GammaRegressor                             -747758712261.32  ...        0.02
# PoissonRegressor              -3516887945724976089268224.00  ...        0.05
#
# [42 rows x 4 columns]
